# %% [markdown]
# # Coursework 1
#
# A Jupyter notebook has a series of cells, which are split into two different types.  There is a Markdown cell (like this one) which allows text to be input in either Markdown or HTML format.  The other type of cell is a code cell, which allows you to run the code written inside it.
#
# When you run a code cell, you will not necessarily see any output, but if you do it will be below the cell.  To check whether it has completed running, look at the `In [ ]` next to the cell.  Whilst it's processing it will be filled with an asterisk (\* symbol), and when it's finished it will increase the number inside it.
#
# Run the code in the following cell by pressing `Crtl` + `Enter`.  If you want to move the focus onto the cell after the code has finished running, use `Shift` + `Enter` instead

# %%
import json
import requests
from pymongo import MongoClient
from datetime import datetime
from unittest import TestCase
print("Success!")
# Out:
# Success!

# %% [markdown]
# # Question 1
#
# Using the API (v2) at http://api.ratings.food.gov.uk, perform the following tasks with the [Python Requests](http://docs.python-requests.org/en/master/) library
# ## Question 1(a)
#
# Write a function `get_local_authorities()` which gets a list of all the local authorities with a parameter `data_format`, which accepts a string.
# - If the parameter is XML it should return the data in XML format, if it is JSON, it should return in JSON format
# - If the parameter is not one of those two strings the function should raise a `ValueError` with an appropriate error message
# - You should return the `requests` object

# %%
def get_local_authorities(data_format):
    headers = {"x-api-version": 2, "accept": "application/{}".format(data_format), "content-type":"application/{}".format(data_format)}
    r = requests.get('http://api.ratings.food.gov.uk/Authorities',headers=headers)
    return r
# Out:
# <Response [200]>

# %%
get_local_authorities("json").json()
# Out:
# {'authorities': [{'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'commercial@aberdeencity.gov.uk',
#    'EstablishmentCount': 1762,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS760en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'aberdeen-city',
#    'LastPublishedDate': '2016-10-12T00:37:35.363',
#    'LocalAuthorityId': 197,
#    'LocalAuthorityIdCode': '760',
#    'Name': 'Aberdeen City',
#    'RegionName': 'Scotland',
#    'SchemeType': 2,
#    'SchemeUrl': '',
#    'Url': 'http://www.aberdeencity.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/197',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'environmental@aberdeenshire.gov.uk',
#    'EstablishmentCount': 1925,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS761en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'aberdeenshire',
#    'LastPublishedDate': '2016-11-05T00:35:58.823',
#    'LocalAuthorityId': 198,
#    'LocalAuthorityIdCode': '761',
#    'Name': 'Aberdeenshire',
#    'RegionName': 'Scotland',
#    'SchemeType': 2,
#    'SchemeUrl': '',
#    'Url': 'http://www.aberdeenshire.gov.uk/',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/198',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'environmental.support@adur-worthing.gov.uk',
#    'EstablishmentCount': 401,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS323en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'adur',
#    'LastPublishedDate': '2016-11-05T00:37:19.09',
#    'LocalAuthorityId': 277,
#    'LocalAuthorityIdCode': '323',
#    'Name': 'Adur',
#    'RegionName': 'South East',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.adur-worthing.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/277',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'environmental.health@allerdale.gov.uk',
#    'EstablishmentCount': 1075,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS055en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'allerdale',
#    'LastPublishedDate': '2016-11-04T00:35:03.203',
#    'LocalAuthorityId': 158,
#    'LocalAuthorityIdCode': '055',
#    'Name': 'Allerdale',
#    'RegionName': 'North West',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.allerdale.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/158',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'envhealth@ambervalley.gov.uk',
#    'EstablishmentCount': 958,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS062en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'amber-valley',
#    'LastPublishedDate': '2016-10-28T00:33:22.91',
#    'LocalAuthorityId': 48,
#    'LocalAuthorityIdCode': '062',
#    'Name': 'Amber Valley',
#    'RegionName': 'East Midlands',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.ambervalley.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/48',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'iechydyramgylchedd@ynysmon.gov.uk',
#    'EstablishmentCount': 628,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS551en-GB.xml',
#    'FileNameWelsh': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS551cy-GB.xml',
#    'FriendlyName': 'anglesey',
#    'LastPublishedDate': '2016-11-04T00:37:40.363',
#    'LocalAuthorityId': 334,
#    'LocalAuthorityIdCode': '551',
#    'Name': 'Anglesey',
#    'RegionName': 'Wales',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.ynysmon.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/334',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'ENVHEALTH@angus.gov.uk',
#    'EstablishmentCount': 880,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS762en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'angus',
#    'LastPublishedDate': '2016-11-04T00:37:18.12',
#    'LocalAuthorityId': 199,
#    'LocalAuthorityIdCode': '762',
#    'Name': 'Angus',
#    'RegionName': 'Scotland',
#    'SchemeType': 2,
#    'SchemeUrl': '',
#    'Url': 'http://www.angus.gov.uk/fhis/',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/199',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'envhealth@antrimandnewtownabbey.gov.uk',
#    'EstablishmentCount': 1106,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS801en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'antrim-and-newtownabbey',
#    'LastPublishedDate': '2016-11-04T00:37:06.69',
#    'LocalAuthorityId': 132,
#    'LocalAuthorityIdCode': '801',
#    'Name': 'Antrim and Newtownabbey',
#    'RegionName': 'Northern Ireland',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.antrimandnewtownabbey.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/132',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'env.health@ardsandnorthdown.gov.uk',
#    'EstablishmentCount': 1057,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS802en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'ards-and-north-down',
#    'LastPublishedDate': '2016-11-04T00:37:08.027',
#    'LocalAuthorityId': 133,
#    'LocalAuthorityIdCode': '802',
#    'Name': 'Ards and North Down',
#    'RegionName': 'Northern Ireland',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.ardsandnorthdown.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/133',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'envhealth@argyll-bute.gov.uk',
#    'EstablishmentCount': 871,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS763en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'argyll-and-bute',
#    'LastPublishedDate': '2016-10-13T00:30:30.96',
#    'LocalAuthorityId': 200,
#    'LocalAuthorityIdCode': '763',
#    'Name': 'Argyll and Bute',
#    'RegionName': 'Scotland',
#    'SchemeType': 2,
#    'SchemeUrl': '',
#    'Url': 'http://www.argyll-bute.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/200',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'ehealth@armaghbanbridgecraigavon.gov.uk',
#    'EstablishmentCount': 1541,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS803en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'armagh-city-banbridge-and-craigavon',
#    'LastPublishedDate': '2016-11-02T00:34:36.64',
#    'LocalAuthorityId': 134,
#    'LocalAuthorityIdCode': '803',
#    'Name': 'Armagh City, Banbridge and Craigavon',
#    'RegionName': 'Northern Ireland',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.armaghbanbridgecraigavon.gov.uk/',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/134',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'food.safety@arun.gov.uk',
#    'EstablishmentCount': 1124,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS324en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'arun',
#    'LastPublishedDate': '2016-10-25T00:35:31.647',
#    'LocalAuthorityId': 278,
#    'LocalAuthorityIdCode': '324',
#    'Name': 'Arun',
#    'RegionName': 'South East',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.arun.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/278',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'info@ashfield-dc.gov.uk',
#    'EstablishmentCount': 895,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS259en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'ashfield',
#    'LastPublishedDate': '2016-11-02T00:34:34.17',
#    'LocalAuthorityId': 77,
#    'LocalAuthorityIdCode': '259',
#    'Name': 'Ashfield',
#    'RegionName': 'East Midlands',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.ashfield-dc.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/77',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'envhealth@ashford.gov.uk',
#    'EstablishmentCount': 1067,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS179en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'ashford',
#    'LastPublishedDate': '2016-11-04T00:37:24.693',
#    'LocalAuthorityId': 249,
#    'LocalAuthorityIdCode': '179',
#    'Name': 'Ashford',
#    'RegionName': 'South East',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.ashford.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/249',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'envhealth@aylesburyvaledc.gov.uk',
#    'EstablishmentCount': 1291,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS021en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'aylesbury-vale',
#    'LastPublishedDate': '2016-11-05T00:37:14.927',
#    'LocalAuthorityId': 229,
#    'LocalAuthorityIdCode': '021',
#    'Name': 'Aylesbury Vale',
#    'RegionName': 'South East',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.aylesburyvaledc.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/229',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'food.safety@babergh.gov.uk',
#    'EstablishmentCount': 878,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS297en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'babergh',
#    'LastPublishedDate': '2016-10-28T00:37:22.467',
#    'LocalAuthorityId': 35,
#    'LocalAuthorityIdCode': '297',
#    'Name': 'Babergh',
#    'RegionName': 'East Counties',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.babergh.gov.uk/',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/35',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'foodsafety@lbbd.gov.uk',
#    'EstablishmentCount': 981,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS501en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'barking-and-dagenham',
#    'LastPublishedDate': '2016-11-04T00:34:37.787',
#    'LocalAuthorityId': 88,
#    'LocalAuthorityIdCode': '501',
#    'Name': 'Barking and Dagenham',
#    'RegionName': 'London',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.lbbd.gov.uk/Pages/Home.aspx',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/88',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'FoodSafety@barnet.gov.uk',
#    'EstablishmentCount': 2090,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS502en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'barnet',
#    'LastPublishedDate': '2016-11-05T00:32:56.67',
#    'LocalAuthorityId': 89,
#    'LocalAuthorityIdCode': '502',
#    'Name': 'Barnet',
#    'RegionName': 'London',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.barnet.gov.uk/',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/89',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'regulatoryservices@barnsley.gov.uk',
#    'EstablishmentCount': 1872,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS401en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'barnsley',
#    'LastPublishedDate': '2016-11-04T00:36:28.993',
#    'LocalAuthorityId': 392,
#    'LocalAuthorityIdCode': '401',
#    'Name': 'Barnsley',
#    'RegionName': 'Yorkshire and Humberside',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.barnsley.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/392',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'commercial@barrowbc.gov.uk',
#    'EstablishmentCount': 569,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS056en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'barrow-in-furness',
#    'LastPublishedDate': '2016-11-03T00:32:05.393',
#    'LocalAuthorityId': 159,
#    'LocalAuthorityIdCode': '056',
#    'Name': 'Barrow-in-Furness',
#    'RegionName': 'North West',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.barrowbc.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/159',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'ehs@basildon.gov.uk',
#    'EstablishmentCount': 1137,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS109en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'basildon',
#    'LastPublishedDate': '2016-11-04T00:34:28.01',
#    'LocalAuthorityId': 6,
#    'LocalAuthorityIdCode': '109',
#    'Name': 'Basildon',
#    'RegionName': 'East Counties',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.basildon.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/6',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'ehteam@basingstoke.gov.uk',
#    'EstablishmentCount': 1043,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS131en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'basingstoke-and-deane',
#    'LastPublishedDate': '2016-11-04T00:32:22.037',
#    'LocalAuthorityId': 238,
#    'LocalAuthorityIdCode': '131',
#    'Name': 'Basingstoke and Deane',
#    'RegionName': 'South East',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.basingstoke.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/238',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'environmental.health@bassetlaw.gov.uk',
#    'EstablishmentCount': 946,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS260en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'bassetlaw',
#    'LastPublishedDate': '2016-11-05T00:32:09.24',
#    'LocalAuthorityId': 78,
#    'LocalAuthorityIdCode': '260',
#    'Name': 'Bassetlaw',
#    'RegionName': 'East Midlands',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.bassetlaw.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/78',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'public_protection@bathnes.gov.uk',
#    'EstablishmentCount': 1752,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS857en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'bath-and-north-east-somerset',
#    'LastPublishedDate': '2016-11-05T00:32:21.62',
#    'LocalAuthorityId': 326,
#    'LocalAuthorityIdCode': '857',
#    'Name': 'Bath and North East Somerset',
#    'RegionName': 'South West',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.bathnes.gov.uk/healthandsocial/foodsafety/Pages/default.aspx',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/326',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'ehadmin@bedford.gov.uk',
#    'EstablishmentCount': 1382,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS701en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'bedford',
#    'LastPublishedDate': '2016-11-04T00:38:22.933',
#    'LocalAuthorityId': 42,
#    'LocalAuthorityIdCode': '701',
#    'Name': 'Bedford',
#    'RegionName': 'East Counties',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.bedford.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/42',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'envhealth@belfastcity.gov.uk',
#    'EstablishmentCount': 3039,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS807en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'belfast-city',
#    'LastPublishedDate': '2016-11-04T00:35:00.823',
#    'LocalAuthorityId': 138,
#    'LocalAuthorityIdCode': '807',
#    'Name': 'Belfast City',
#    'RegionName': 'Northern Ireland',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.belfastcity.gov.uk/buildingcontrol-environment/foodsafety/consumers-foodhygienescheme.aspx',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/138',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'food.safety@bexley.gov.uk',
#    'EstablishmentCount': 1347,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS503en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'bexley',
#    'LastPublishedDate': '2016-11-04T00:34:39.587',
#    'LocalAuthorityId': 90,
#    'LocalAuthorityIdCode': '503',
#    'Name': 'Bexley',
#    'RegionName': 'London',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.bexley.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/90',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'nick.lowe@birmingham.gov.uk',
#    'EstablishmentCount': 6329,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS402en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'birmingham',
#    'LastPublishedDate': '2016-11-04T00:36:22.237',
#    'LocalAuthorityId': 374,
#    'LocalAuthorityIdCode': '402',
#    'Name': 'Birmingham',
#    'RegionName': 'West Midlands',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.birmingham.gov.uk/environmental-health',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/374',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'environmental.health@blaby.gov.uk',
#    'EstablishmentCount': 608,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS209en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'blaby',
#    'LastPublishedDate': '2016-10-29T00:34:46.807',
#    'LocalAuthorityId': 56,
#    'LocalAuthorityIdCode': '209',
#    'Name': 'Blaby',
#    'RegionName': 'East Midlands',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.blaby.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/56',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'publicprotection@blackburn.gov.uk',
#    'EstablishmentCount': 1224,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS897en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'blackburn',
#    'LastPublishedDate': '2016-11-04T00:31:54.227',
#    'LocalAuthorityId': 195,
#    'LocalAuthorityIdCode': '897',
#    'Name': 'Blackburn',
#    'RegionName': 'North West',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.blackburn.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/195',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'foodcontrol@blackpool.gov.uk',
#    'EstablishmentCount': 1782,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS898en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'blackpool',
#    'LastPublishedDate': '2016-11-02T00:31:57.32',
#    'LocalAuthorityId': 196,
#    'LocalAuthorityIdCode': '898',
#    'Name': 'Blackpool',
#    'RegionName': 'North West',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.blackpool.gov.uk/Services/A-F/FoodHygiene/',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/196',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'environmental.health@blaenau-gwent.gov.uk',
#    'EstablishmentCount': 567,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS552en-GB.xml',
#    'FileNameWelsh': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS552cy-GB.xml',
#    'FriendlyName': 'blaenau-gwent',
#    'LastPublishedDate': '2016-10-15T00:36:48.733',
#    'LocalAuthorityId': 335,
#    'LocalAuthorityIdCode': '552',
#    'Name': 'Blaenau Gwent',
#    'RegionName': 'Wales',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.blaenau-gwent.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/335',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'enquiries@bolsover.gov.uk',
#    'EstablishmentCount': 664,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS063en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'bolsover',
#    'LastPublishedDate': '2016-11-04T00:36:42.027',
#    'LocalAuthorityId': 49,
#    'LocalAuthorityIdCode': '063',
#    'Name': 'Bolsover',
#    'RegionName': 'East Midlands',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.bolsover.gov.uk/',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/49',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'environmental.health@bolton.gov.uk',
#    'EstablishmentCount': 2241,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS403en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'bolton',
#    'LastPublishedDate': '2016-11-05T00:32:35.887',
#    'LocalAuthorityId': 176,
#    'LocalAuthorityIdCode': '403',
#    'Name': 'Bolton',
#    'RegionName': 'North West',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.bolton.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/176',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'env.serv@boston.gov.uk',
#    'EstablishmentCount': 581,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS219en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'boston',
#    'LastPublishedDate': '2016-11-04T00:36:43.557',
#    'LocalAuthorityId': 63,
#    'LocalAuthorityIdCode': '219',
#    'Name': 'Boston',
#    'RegionName': 'East Midlands',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.boston.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/63',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'foodandhealthandsafety@bournemouth.gov.uk',
#    'EstablishmentCount': 1913,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS872en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'bournemouth',
#    'LastPublishedDate': '2016-11-04T00:39:41.907',
#    'LocalAuthorityId': 328,
#    'LocalAuthorityIdCode': '872',
#    'Name': 'Bournemouth',
#    'RegionName': 'South West',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.bournemouth.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/328',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'environmental.health@bracknell-forest.gov.uk',
#    'EstablishmentCount': 717,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS882en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'bracknell-forest',
#    'LastPublishedDate': '2016-11-04T00:35:29.293',
#    'LocalAuthorityId': 289,
#    'LocalAuthorityIdCode': '882',
#    'Name': 'Bracknell Forest',
#    'RegionName': 'South East',
#    'SchemeType': 1,
#    'SchemeUrl': 'http://www.bracknell-forest.gov.uk/foodsafetyinspection',
#    'Url': 'http://www.bracknell-forest.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/289',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'eh.admin@bradford.gov.uk',
#    'EstablishmentCount': 3992,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS404en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'bradford',
#    'LastPublishedDate': '2016-11-05T00:36:48.503',
#    'LocalAuthorityId': 393,
#    'LocalAuthorityIdCode': '404',
#    'Name': 'Bradford',
#    'RegionName': 'Yorkshire and Humberside',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.bradford.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/393',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'health_protection@braintree.gov.uk',
#    'EstablishmentCount': 1076,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS110en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'braintree',
#    'LastPublishedDate': '2016-11-04T00:34:29.207',
#    'LocalAuthorityId': 7,
#    'LocalAuthorityIdCode': '110',
#    'Name': 'Braintree',
#    'RegionName': 'East Counties',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.braintree.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/7',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'eh.bst@breckland.gov.uk',
#    'EstablishmentCount': 1260,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS227en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'breckland',
#    'LastPublishedDate': '2016-11-05T00:31:59.61',
#    'LocalAuthorityId': 28,
#    'LocalAuthorityIdCode': '227',
#    'Name': 'Breckland',
#    'RegionName': 'East Counties',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.breckland.gov.uk/',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/28',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'ens.foodsafety@brent.gov.uk',
#    'EstablishmentCount': 1976,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS504en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'brent',
#    'LastPublishedDate': '2016-11-02T00:37:43.54',
#    'LocalAuthorityId': 91,
#    'LocalAuthorityIdCode': '504',
#    'Name': 'Brent',
#    'RegionName': 'London',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.brent.gov.uk/',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/91',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'envhealth@brentwood.gov.uk',
#    'EstablishmentCount': 637,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS111en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'brentwood',
#    'LastPublishedDate': '2016-11-04T00:34:30.057',
#    'LocalAuthorityId': 8,
#    'LocalAuthorityIdCode': '111',
#    'Name': 'Brentwood',
#    'RegionName': 'East Counties',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.brentwood.gov.uk/',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/8',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'publicprotection@bridgend.gov.uk',
#    'EstablishmentCount': 1045,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS553en-GB.xml',
#    'FileNameWelsh': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS553cy-GB.xml',
#    'FriendlyName': 'bridgend',
#    'LastPublishedDate': '2016-11-04T00:33:23.813',
#    'LocalAuthorityId': 336,
#    'LocalAuthorityIdCode': '553',
#    'Name': 'Bridgend',
#    'RegionName': 'Wales',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.bridgend.gov.uk/',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/336',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'ehl.food@brighton-hove.gov.uk',
#    'EstablishmentCount': 3089,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS875en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'brighton-and-hove',
#    'LastPublishedDate': '2016-11-04T00:32:42.317',
#    'LocalAuthorityId': 286,
#    'LocalAuthorityIdCode': '875',
#    'Name': 'Brighton and Hove',
#    'RegionName': 'South East',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.brighton-hove.gov.uk/foodsafety',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/286',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'food.safety@bristol.gov.uk',
#    'EstablishmentCount': 4579,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS855en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'bristol',
#    'LastPublishedDate': '2016-11-04T00:35:46.27',
#    'LocalAuthorityId': 324,
#    'LocalAuthorityIdCode': '855',
#    'Name': 'Bristol',
#    'RegionName': 'South West',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.bristol.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/324',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'environ.enforcement@broadland.gov.uk',
#    'EstablishmentCount': 860,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS228en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'broadland',
#    'LastPublishedDate': '2016-11-05T00:37:08.047',
#    'LocalAuthorityId': 29,
#    'LocalAuthorityIdCode': '228',
#    'Name': 'Broadland',
#    'RegionName': 'East Counties',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.broadland.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/29',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'food@bromley.gov.uk',
#    'EstablishmentCount': 1739,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS505en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'bromley',
#    'LastPublishedDate': '2016-11-04T00:38:37.96',
#    'LocalAuthorityId': 92,
#    'LocalAuthorityIdCode': '505',
#    'Name': 'Bromley',
#    'RegionName': 'London',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.bromley.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/92',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'enquiries@worcestershire.gov.uk',
#    'EstablishmentCount': 662,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS145en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'bromsgrove',
#    'LastPublishedDate': '2016-11-05T00:31:09.94',
#    'LocalAuthorityId': 355,
#    'LocalAuthorityIdCode': '145',
#    'Name': 'Bromsgrove',
#    'RegionName': 'West Midlands',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.worcsregservices.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/355',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'envhealth@broxbourne.gov.uk',
#    'EstablishmentCount': 638,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS155en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'broxbourne',
#    'LastPublishedDate': '2016-11-03T00:30:20.13',
#    'LocalAuthorityId': 18,
#    'LocalAuthorityIdCode': '155',
#    'Name': 'Broxbourne',
#    'RegionName': 'East Counties',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.broxbourne.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/18',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'health@broxtowe.gov.uk',
#    'EstablishmentCount': 852,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS261en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'broxtowe',
#    'LastPublishedDate': '2016-11-04T00:30:44.83',
#    'LocalAuthorityId': 79,
#    'LocalAuthorityIdCode': '261',
#    'Name': 'Broxtowe',
#    'RegionName': 'East Midlands',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.broxtowe.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/79',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'envhealth@burnley.gov.uk',
#    'EstablishmentCount': 866,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS196en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'burnley',
#    'LastPublishedDate': '2016-11-02T00:35:55.987',
#    'LocalAuthorityId': 164,
#    'LocalAuthorityIdCode': '196',
#    'Name': 'Burnley',
#    'RegionName': 'North West',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.burnley.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/164',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'Foodsafety@bury.gov.uk',
#    'EstablishmentCount': 868,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS405en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'bury',
#    'LastPublishedDate': '2016-10-18T00:34:17.357',
#    'LocalAuthorityId': 177,
#    'LocalAuthorityIdCode': '405',
#    'Name': 'Bury',
#    'RegionName': 'North West',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.bury.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/177',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'foodhealthandsafety@caerphilly.gov.uk',
#    'EstablishmentCount': 1264,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS555en-GB.xml',
#    'FileNameWelsh': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS555cy-GB.xml',
#    'FriendlyName': 'caerphilly',
#    'LastPublishedDate': '2016-11-05T00:36:58.83',
#    'LocalAuthorityId': 338,
#    'LocalAuthorityIdCode': '555',
#    'Name': 'Caerphilly',
#    'RegionName': 'Wales',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.caerphilly.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/338',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'environmental.health@calderdale.gov.uk',
#    'EstablishmentCount': 2091,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS406en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'calderdale',
#    'LastPublishedDate': '2016-11-04T00:40:07.11',
#    'LocalAuthorityId': 394,
#    'LocalAuthorityIdCode': '406',
#    'Name': 'Calderdale',
#    'RegionName': 'Yorkshire and Humberside',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.calderdale.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/394',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'env.health@cambridge.gov.uk',
#    'EstablishmentCount': 1277,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS027en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'cambridge-city',
#    'LastPublishedDate': '2016-11-05T00:30:28.173',
#    'LocalAuthorityId': 1,
#    'LocalAuthorityIdCode': '027',
#    'Name': 'Cambridge City',
#    'RegionName': 'East Counties',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.cambridge.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/1',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'planningandpublicprotection@camden.gov.uk',
#    'EstablishmentCount': 2867,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS506en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'camden',
#    'LastPublishedDate': '2016-11-03T00:30:57.227',
#    'LocalAuthorityId': 93,
#    'LocalAuthorityIdCode': '506',
#    'Name': 'Camden',
#    'RegionName': 'London',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.camden.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/93',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'environmentalhealth@cannockchasedc.gov.uk',
#    'EstablishmentCount': 774,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS287en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'cannock-chase',
#    'LastPublishedDate': '2016-11-05T00:37:19.94',
#    'LocalAuthorityId': 361,
#    'LocalAuthorityIdCode': '287',
#    'Name': 'Cannock Chase',
#    'RegionName': 'West Midlands',
#    'SchemeType': 1,
#    'SchemeUrl': 'http://www.ratemyplace.org.uk/',
#    'Url': 'http://www.cannockchasedc.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/361',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'food@canterbury.gov.uk',
#    'EstablishmentCount': 1452,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS180en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'canterbury-city',
#    'LastPublishedDate': '2016-11-01T00:37:01.96',
#    'LocalAuthorityId': 250,
#    'LocalAuthorityIdCode': '180',
#    'Name': 'Canterbury City',
#    'RegionName': 'South East',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.canterbury.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/250',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'foodteam@cardiff.gov.uk',
#    'EstablishmentCount': 2817,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS556en-GB.xml',
#    'FileNameWelsh': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS556cy-GB.xml',
#    'FriendlyName': 'cardiff',
#    'LastPublishedDate': '2016-11-05T00:34:52.867',
#    'LocalAuthorityId': 339,
#    'LocalAuthorityIdCode': '556',
#    'Name': 'Cardiff',
#    'RegionName': 'Wales',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.cardiff.gov.uk/foodsafety',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/339',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'Environmentalhealth@carlisle.gov.uk',
#    'EstablishmentCount': 792,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS057en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'carlisle-city',
#    'LastPublishedDate': '2016-11-04T00:39:03.41',
#    'LocalAuthorityId': 160,
#    'LocalAuthorityIdCode': '057',
#    'Name': 'Carlisle City',
#    'RegionName': 'North West',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.carlisle.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/160',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'PublicProtection@carmarthenshire.gov.uk',
#    'EstablishmentCount': 1645,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS558en-GB.xml',
#    'FileNameWelsh': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS558cy-GB.xml',
#    'FriendlyName': 'carmarthenshire',
#    'LastPublishedDate': '2016-11-05T00:34:43.29',
#    'LocalAuthorityId': 341,
#    'LocalAuthorityIdCode': '558',
#    'Name': 'Carmarthenshire',
#    'RegionName': 'Wales',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.carmarthenshire.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/341',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'environmentalhealth@castlepoint.gov.uk',
#    'EstablishmentCount': 487,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS112en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'castle-point',
#    'LastPublishedDate': '2016-10-28T00:37:40.327',
#    'LocalAuthorityId': 9,
#    'LocalAuthorityIdCode': '112',
#    'Name': 'Castle Point',
#    'RegionName': 'East Counties',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.castlepoint.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/9',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'environmental.health@causewaycoastandglens.gov.uk',
#    'EstablishmentCount': 1470,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS805en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'causeway-coast-and-glens',
#    'LastPublishedDate': '2016-11-03T00:32:02.26',
#    'LocalAuthorityId': 136,
#    'LocalAuthorityIdCode': '805',
#    'Name': 'Causeway Coast and Glens',
#    'RegionName': 'Northern Ireland',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.causewaycoastandglens.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/136',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'env.health@centralbedfordshire.gov.uk',
#    'EstablishmentCount': 1268,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS702en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'central-bedfordshire',
#    'LastPublishedDate': '2016-11-04T00:30:27.92',
#    'LocalAuthorityId': 43,
#    'LocalAuthorityIdCode': '702',
#    'Name': 'Central Bedfordshire',
#    'RegionName': 'East Counties',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.centralbedfordshire.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/43',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'envhealth@ceredigion.gov.uk',
#    'EstablishmentCount': 1091,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS557en-GB.xml',
#    'FileNameWelsh': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS557cy-GB.xml',
#    'FriendlyName': 'ceredigion',
#    'LastPublishedDate': '2016-11-05T00:33:09.723',
#    'LocalAuthorityId': 340,
#    'LocalAuthorityIdCode': '557',
#    'Name': 'Ceredigion',
#    'RegionName': 'Wales',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.ceredigion.gov.uk/',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/340',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'food.hygiene@charnwood.gov.uk',
#    'EstablishmentCount': 1326,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS210en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'charnwood',
#    'LastPublishedDate': '2016-11-05T00:33:50.59',
#    'LocalAuthorityId': 57,
#    'LocalAuthorityIdCode': '210',
#    'Name': 'Charnwood',
#    'RegionName': 'East Midlands',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.charnwood.gov.uk/',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/57',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'safesupport@chelmsford.gov.uk',
#    'EstablishmentCount': 1119,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS113en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'chelmsford',
#    'LastPublishedDate': '2016-11-04T00:38:18',
#    'LocalAuthorityId': 10,
#    'LocalAuthorityIdCode': '113',
#    'Name': 'Chelmsford',
#    'RegionName': 'East Counties',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.chelmsford.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/10',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'ehbusinesssupport@cheltenham.gov.uk',
#    'EstablishmentCount': 1004,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS124en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'cheltenham',
#    'LastPublishedDate': '2016-11-01T00:30:22.08',
#    'LocalAuthorityId': 310,
#    'LocalAuthorityIdCode': '124',
#    'Name': 'Cheltenham',
#    'RegionName': 'South West',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.cheltenham.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/310',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'public.protection@cherwell-dc.gov.uk',
#    'EstablishmentCount': 1053,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS268en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'cherwell',
#    'LastPublishedDate': '2016-10-29T00:34:24.223',
#    'LocalAuthorityId': 261,
#    'LocalAuthorityIdCode': '268',
#    'Name': 'Cherwell',
#    'RegionName': 'South East',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.cherwell.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/261',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'commercialservices@cheshireeast.gov.uk',
#    'EstablishmentCount': 2327,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS703en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'cheshire-east',
#    'LastPublishedDate': '2016-10-28T00:36:07.703',
#    'LocalAuthorityId': 191,
#    'LocalAuthorityIdCode': '703',
#    'Name': 'Cheshire East',
#    'RegionName': 'North West',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.cheshireeast.gov.uk/',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/191',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'foodsafety@cheshirewestandchester.gov.uk',
#    'EstablishmentCount': 2994,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS704en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'cheshire-west-and-chester',
#    'LastPublishedDate': '2016-11-04T00:35:15.59',
#    'LocalAuthorityId': 192,
#    'LocalAuthorityIdCode': '704',
#    'Name': 'Cheshire West and Chester',
#    'RegionName': 'North West',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.cheshirewestandchester.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/192',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'food@chesterfield.gov.uk',
#    'EstablishmentCount': 897,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS064en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'chesterfield',
#    'LastPublishedDate': '2016-11-04T00:36:42.927',
#    'LocalAuthorityId': 50,
#    'LocalAuthorityIdCode': '064',
#    'Name': 'Chesterfield',
#    'RegionName': 'East Midlands',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.chesterfield.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/50',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'environmentalhealth@chichester.gov.uk',
#    'EstablishmentCount': 1310,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS325en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'chichester',
#    'LastPublishedDate': '2016-11-05T00:36:55.41',
#    'LocalAuthorityId': 279,
#    'LocalAuthorityIdCode': '325',
#    'Name': 'Chichester',
#    'RegionName': 'South East',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.chichester.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/279',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'envhealth@chiltern.gov.uk',
#    'EstablishmentCount': 667,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS022en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'chiltern',
#    'LastPublishedDate': '2016-11-04T00:37:19.52',
#    'LocalAuthorityId': 230,
#    'LocalAuthorityIdCode': '022',
#    'Name': 'Chiltern',
#    'RegionName': 'South East',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.chiltern.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/230',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'contact@chorley.gov.uk',
#    'EstablishmentCount': 835,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS197en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'chorley',
#    'LastPublishedDate': '2016-11-05T00:36:10.687',
#    'LocalAuthorityId': 165,
#    'LocalAuthorityIdCode': '197',
#    'Name': 'Chorley',
#    'RegionName': 'North West',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.chorley.gov.uk/foodratings',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/165',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'environmental.services@christchurch.gov.uk',
#    'EstablishmentCount': 322,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS084en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'christchurch',
#    'LastPublishedDate': '2016-10-27T00:33:01.487',
#    'LocalAuthorityId': 304,
#    'LocalAuthorityIdCode': '084',
#    'Name': 'Christchurch',
#    'RegionName': 'South West',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.dorsetforyou.com',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/304',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'publicprotection@cityoflondon.gov.uk',
#    'EstablishmentCount': 1851,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS508en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'city-of-london-corporation',
#    'LastPublishedDate': '2016-11-03T00:31:06',
#    'LocalAuthorityId': 95,
#    'LocalAuthorityIdCode': '508',
#    'Name': 'City of London Corporation',
#    'RegionName': 'London',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/95',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'ehealth@clacks.gov.uk',
#    'EstablishmentCount': 437,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS768en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'clackmannanshire',
#    'LastPublishedDate': '2016-11-05T00:34:37.62',
#    'LocalAuthorityId': 205,
#    'LocalAuthorityIdCode': '768',
#    'Name': 'Clackmannanshire',
#    'RegionName': 'Scotland',
#    'SchemeType': 2,
#    'SchemeUrl': '',
#    'Url': 'http://www.clacksweb.org.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/205',
#      'rel': 'self'}]},
# ...
#    'FileNameWelsh': None,
#    'FriendlyName': 'west-devon',
#    'LastPublishedDate': '2016-10-21T00:34:13.06',
#    'LocalAuthorityId': 303,
#    'LocalAuthorityIdCode': '081',
#    'Name': 'West Devon',
#    'RegionName': 'South West',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.westdevon.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/303',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'env.health@westdorset-dc.gov.uk',
#    'EstablishmentCount': 1029,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS089en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'west-dorset',
#    'LastPublishedDate': '2016-11-04T00:35:34.027',
#    'LocalAuthorityId': 308,
#    'LocalAuthorityIdCode': '089',
#    'Name': 'West Dorset',
#    'RegionName': 'South West',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.dorsetforyou.com',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/308',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'environmental.health@west-dunbarton.gov.uk',
#    'EstablishmentCount': 743,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS769en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'west-dunbartonshire',
#    'LastPublishedDate': '2016-11-05T00:34:36.713',
#    'LocalAuthorityId': 206,
#    'LocalAuthorityIdCode': '769',
#    'Name': 'West Dunbartonshire',
#    'RegionName': 'Scotland',
#    'SchemeType': 2,
#    'SchemeUrl': '',
#    'Url': 'http://www.west-dunbarton.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/206',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'EnvHealth.Admin@westlancs.gov.uk',
#    'EstablishmentCount': 855,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS206en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'west-lancashire',
#    'LastPublishedDate': '2016-11-02T00:37:20.04',
#    'LocalAuthorityId': 174,
#    'LocalAuthorityIdCode': '206',
#    'Name': 'West Lancashire',
#    'RegionName': 'North West',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.westlancs.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/174',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'food.healthandsafety@west-lindsey.gov.uk',
#    'EstablishmentCount': 805,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS225en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'west-lindsey',
#    'LastPublishedDate': '2016-11-04T00:38:28.477',
#    'LocalAuthorityId': 69,
#    'LocalAuthorityIdCode': '225',
#    'Name': 'West Lindsey',
#    'RegionName': 'East Midlands',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'https://www.west-lindsey.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/69',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'environmentalhealth@westlothian.gov.uk',
#    'EstablishmentCount': 1092,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS782en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'west-lothian',
#    'LastPublishedDate': '2016-11-05T00:30:33.09',
#    'LocalAuthorityId': 219,
#    'LocalAuthorityIdCode': '782',
#    'Name': 'West Lothian',
#    'RegionName': 'Scotland',
#    'SchemeType': 2,
#    'SchemeUrl': '',
#    'Url': 'http://www.westlothian.gov.uk/',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/219',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'ERS@2020partnership.uk',
#    'EstablishmentCount': 951,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS272en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'west-oxfordshire',
#    'LastPublishedDate': '2016-11-04T00:37:26.53',
#    'LocalAuthorityId': 265,
#    'LocalAuthorityIdCode': '272',
#    'Name': 'West Oxfordshire',
#    'RegionName': 'South East',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.westoxon.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/265',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'licensingenvhealth@westsomerset.gov.uk',
#    'EstablishmentCount': 552,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS285en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'west-somerset',
#    'LastPublishedDate': '2016-11-05T00:37:18.453',
#    'LocalAuthorityId': 320,
#    'LocalAuthorityIdCode': '285',
#    'Name': 'West Somerset',
#    'RegionName': 'South West',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.westsomersetonline.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/320',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'foodsafety@westminster.gov.uk',
#    'EstablishmentCount': 4370,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS533en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'westminster',
#    'LastPublishedDate': '2016-11-04T00:31:11.237',
#    'LocalAuthorityId': 120,
#    'LocalAuthorityIdCode': '533',
#    'Name': 'Westminster',
#    'RegionName': 'London',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.westminster.gov.uk/',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/120',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'envhealth@weymouth.gov.uk',
#    'EstablishmentCount': 438,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS090en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'weymouth-and-portland',
#    'LastPublishedDate': '2016-11-04T00:35:34.527',
#    'LocalAuthorityId': 309,
#    'LocalAuthorityIdCode': '090',
#    'Name': 'Weymouth and Portland',
#    'RegionName': 'South West',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.dorsetforyou.com',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/309',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'comm@wigan.gov.uk',
#    'EstablishmentCount': 2105,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS434en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'wigan',
#    'LastPublishedDate': '2016-11-05T00:33:18.467',
#    'LocalAuthorityId': 189,
#    'LocalAuthorityIdCode': '434',
#    'Name': 'Wigan',
#    'RegionName': 'North West',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.wigan.gov.uk/',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/189',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'publicprotectioneast@wiltshire.gov.uk',
#    'EstablishmentCount': 4598,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS709en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'wiltshire',
#    'LastPublishedDate': '2016-11-05T00:33:37.363',
#    'LocalAuthorityId': 323,
#    'LocalAuthorityIdCode': '709',
#    'Name': 'Wiltshire',
#    'RegionName': 'South West',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.wiltshire.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/323',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'healthprotection@winchester.gov.uk',
#    'EstablishmentCount': 780,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS143en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'winchester-city',
#    'LastPublishedDate': '2016-11-01T00:36:45.48',
#    'LocalAuthorityId': 248,
#    'LocalAuthorityIdCode': '143',
#    'Name': 'Winchester City',
#    'RegionName': 'South East',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.winchester.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/248',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'customer.service@rbwm.gov.uk',
#    'EstablishmentCount': 1262,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS886en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'windsor-and-maidenhead',
#    'LastPublishedDate': '2016-10-28T00:37:59.267',
#    'LocalAuthorityId': 293,
#    'LocalAuthorityIdCode': '886',
#    'Name': 'Windsor and Maidenhead',
#    'RegionName': 'South East',
#    'SchemeType': 1,
#    'SchemeUrl': 'http://www.rbwm.gov.uk/web/eh_catering_for_health.htm ',
#    'Url': 'http://www.rbwm.gov.uk/',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/293',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'environmentalhealth@wirral.gov.uk',
#    'EstablishmentCount': 2208,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS435en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'wirral',
#    'LastPublishedDate': '2016-11-04T00:35:12.3',
#    'LocalAuthorityId': 190,
#    'LocalAuthorityIdCode': '435',
#    'Name': 'Wirral',
#    'RegionName': 'North West',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.wirral.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/190',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'emma.bourne@woking.gov.uk',
#    'EstablishmentCount': 749,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS315en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'woking',
#    'LastPublishedDate': '2016-11-04T00:39:32.113',
#    'LocalAuthorityId': 276,
#    'LocalAuthorityIdCode': '315',
#    'Name': 'Woking',
#    'RegionName': 'South East',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.woking.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/276',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'environmental.health@wokingham.gov.uk',
#    'EstablishmentCount': 881,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS887en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'wokingham',
#    'LastPublishedDate': '2016-11-04T00:39:37.15',
#    'LocalAuthorityId': 294,
#    'LocalAuthorityIdCode': '887',
#    'Name': 'Wokingham',
#    'RegionName': 'South East',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.wokingham.gov.uk/welcome/',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/294',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'environmentalhealth@wolverhampton.gov.uk',
#    'EstablishmentCount': 1817,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS436en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'wolverhampton',
#    'LastPublishedDate': '2016-11-04T00:40:04.17',
#    'LocalAuthorityId': 380,
#    'LocalAuthorityIdCode': '436',
#    'Name': 'Wolverhampton',
#    'RegionName': 'West Midlands',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.wolverhampton.gov.uk/',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/380',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'enquiries@worcsregservices.gov.uk',
#    'EstablishmentCount': 771,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS151en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'worcester-city',
#    'LastPublishedDate': '2016-11-04T00:36:08.003',
#    'LocalAuthorityId': 358,
#    'LocalAuthorityIdCode': '151',
#    'Name': 'Worcester City',
#    'RegionName': 'West Midlands',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.worcsregservices.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/358',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'environmental.support@adur-worthing.gov.uk',
#    'EstablishmentCount': 869,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS329en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'worthing',
#    'LastPublishedDate': '2016-11-05T00:36:23.697',
#    'LocalAuthorityId': 283,
#    'LocalAuthorityIdCode': '329',
#    'Name': 'Worthing',
#    'RegionName': 'South East',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.adur-worthing.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/283',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'public_protection_service@wrexham.gov.uk',
#    'EstablishmentCount': 1070,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS571en-GB.xml',
#    'FileNameWelsh': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS571cy-GB.xml',
#    'FriendlyName': 'wrexham',
#    'LastPublishedDate': '2016-11-04T00:33:51.347',
#    'LocalAuthorityId': 354,
#    'LocalAuthorityIdCode': '571',
#    'Name': 'Wrexham',
#    'RegionName': 'Wales',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.wrexham.gov.uk/',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/354',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'wrsenquiries@worcsregservices.gov.uk',
#    'EstablishmentCount': 919,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS152en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'wychavon',
#    'LastPublishedDate': '2016-11-04T00:36:09.1',
#    'LocalAuthorityId': 359,
#    'LocalAuthorityIdCode': '152',
#    'Name': 'Wychavon',
#    'RegionName': 'West Midlands',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.worcsregservices.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/359',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'Food.Ratings@wycombe.gov.uk',
#    'EstablishmentCount': 1003,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS025en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'wycombe',
#    'LastPublishedDate': '2016-11-04T00:37:22.207',
#    'LocalAuthorityId': 232,
#    'LocalAuthorityIdCode': '025',
#    'Name': 'Wycombe',
#    'RegionName': 'South East',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.wycombe.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/232',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'mailroom@wyre.gov.uk',
#    'EstablishmentCount': 939,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS207en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'wyre',
#    'LastPublishedDate': '2016-11-04T00:35:06.027',
#    'LocalAuthorityId': 175,
#    'LocalAuthorityIdCode': '207',
#    'Name': 'Wyre',
#    'RegionName': 'North West',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'https://wyre.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/175',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'enquiries@worcsregservices.gov.uk',
#    'EstablishmentCount': 683,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS153en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'wyre-forest',
#    'LastPublishedDate': '2016-11-04T00:39:58.073',
#    'LocalAuthorityId': 360,
#    'LocalAuthorityIdCode': '153',
#    'Name': 'Wyre Forest',
#    'RegionName': 'West Midlands',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.worcsregservices.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/360',
#      'rel': 'self'}]},
#   {'CreationDate': '2010-08-17T15:30:24.87',
#    'Email': 'food.safety@york.gov.uk',
#    'EstablishmentCount': 2041,
#    'FileName': 'http://ratings.food.gov.uk/OpenDataFiles/FHRS868en-GB.xml',
#    'FileNameWelsh': None,
#    'FriendlyName': 'york',
#    'LastPublishedDate': '2016-11-04T00:36:30.977',
#    'LocalAuthorityId': 406,
#    'LocalAuthorityIdCode': '868',
#    'Name': 'York',
#    'RegionName': 'Yorkshire and Humberside',
#    'SchemeType': 1,
#    'SchemeUrl': '',
#    'Url': 'http://www.york.gov.uk',
#    'links': [{'href': 'http://api.ratings.food.gov.uk/authorities/406',
#      'rel': 'self'}]}],
#  'links': [{'href': 'http://api.ratings.food.gov.uk/authorities',
#    'rel': 'self'}],
#  'meta': {'dataSource': 'API',
#   'extractDate': '2016-11-05T13:20:05.4501387+00:00',
#   'itemCount': 392,
#   'pageNumber': 1,
#   'pageSize': 392,
#   'returncode': 'OK',
#   'totalCount': 392,
#   'totalPages': 1}}

# %%
r = get_local_authorities("xml")
r.text
# Out:
# '<AuthorityDetailCollection xmlns:i="http://www.w3.org/2001/XMLSchema-instance" xmlns="http://schemas.datacontract.org/2004/07/FHRS.Model.Detailed"><links xmlns="http://schemas.datacontract.org/2004/07/FHRS.Model.MetaLinks"><link><href>http://api.ratings.food.gov.uk/authorities</href><rel>self</rel></link></links><meta xmlns="http://schemas.datacontract.org/2004/07/FHRS.Model.MetaLinks"><dataSource>API</dataSource><extractDate>2016-11-05T13:23:24.4505417+00:00</extractDate><itemCount>392</itemCount><pageNumber>1</pageNumber><pageSize>392</pageSize><returncode>OK</returncode><totalCount>392</totalCount><totalPages>1</totalPages></meta><authorities><authority><links xmlns="http://schemas.datacontract.org/2004/07/FHRS.Model.MetaLinks"><link><href>http://api.ratings.food.gov.uk/authorities/197</href><rel>self</rel></link></links><CreationDate>2010-08-17T15:30:24.87</CreationDate><Email>commercial@aberdeencity.gov.uk</Email><EstablishmentCount>1762</EstablishmentCount><FileName>http://ratings.food.gov.uk/OpenDataFiles/FHRS760en-GB.xml</FileName><FileNameWelsh i:nil="true" /><FriendlyName>aberdeen-city</FriendlyName><LastPublishedDate>2016-10-12T00:37:35.363</LastPublishedDate><LocalAuthorityId>197</LocalAuthorityId><LocalAuthorityIdCode>760</LocalAuthorityIdCode><Name>Aberdeen City</Name><RegionName>Scotland</RegionName><SchemeType>2</SchemeType><SchemeUrl></SchemeUrl><Url>http://www.aberdeencity.gov.uk</Url></authority><authority><links xmlns="http://schemas.datacontract.org/2004/07/FHRS.Model.MetaLinks"><link><href>http://api.ratings.food.gov.uk/authorities/198</href><rel>self</rel></link></links><CreationDate>2010-08-17T15:30:24.87</CreationDate><Email>environmental@aberdeenshire.gov.uk</Email><EstablishmentCount>1925</EstablishmentCount><FileName>http://ratings.food.gov.uk/OpenDataFiles/FHRS761en-GB.xml</FileName><FileNameWelsh i:nil="true" /><FriendlyName>aberdeenshire</FriendlyName><LastPublishedDate>2016-11-05T00:35:58.823</LastPublishedDate><LocalAuthorityId>198</LocalAuthorityId><LocalAuthorityIdCode>761</LocalAuthorityIdCode><Name>Aberdeenshire</Name><RegionName>Scotland</RegionName><SchemeType>2</SchemeType><SchemeUrl></SchemeUrl><Url>http://www.aberdeenshire.gov.uk/</Url></authority><authority><links xmlns="http://schemas.datacontract.org/2004/07/FHRS.Model.MetaLinks"><link><href>http://api.ratings.food.gov.uk/authorities/277</href><rel>self</rel></link></links><CreationDate>2010-08-17T15:30:24.87</CreationDate><Email>environmental.support@adur-worthing.gov.uk</Email><EstablishmentCount>401</EstablishmentCount><FileName>http://ratings.food.gov.uk/OpenDataFiles/FHRS323en-GB.xml</FileName><FileNameWelsh i:nil="true" /><FriendlyName>adur</FriendlyName><LastPublishedDate>2016-11-05T00:37:19.09</LastPublishedDate><LocalAuthorityId>277</LocalAuthorityId><LocalAuthorityIdCode>323</LocalAuthorityIdCode><Name>Adur</Name><RegionName>South East</RegionName><SchemeType>1</SchemeType><SchemeUrl></SchemeUrl><Url>http://www.adur-worthing.gov.uk</Url></authority><authority><links xmlns="http://schemas.datacontract.org/2004/07/FHRS.Model.MetaLinks"><link><href>http://api.ratings.food.gov.uk/authorities/158</href><rel>self</rel></link></links><CreationDate>2010-08-17T15:30:24.87</CreationDate><Email>environmental.health@allerdale.gov.uk</Email><EstablishmentCount>1075</EstablishmentCount><FileName>http://ratings.food.gov.uk/OpenDataFiles/FHRS055en-GB.xml</FileName><FileNameWelsh i:nil="true" /><FriendlyName>allerdale</FriendlyName><LastPublishedDate>2016-11-04T00:35:03.203</LastPublishedDate><LocalAuthorityId>158</LocalAuthorityId><LocalAuthorityIdCode>055</LocalAuthorityIdCode><Name>Allerdale</Name><RegionName>North West</RegionName><SchemeType>1</SchemeType><SchemeUrl></SchemeUrl><Url>http://www.allerdale.gov.uk</Url></authority><authority><links xmlns="http://schemas.datacontract.org/2004/07/FHRS.Model.MetaLinks"><link><href>http://api.ratings.food.gov.uk/authorities/48</href><rel>self</rel></link></links><CreationDate>2010-08-17T15:3 ...

# %% [markdown]
# ## Question 1(b)
#
# Write a function `get_establishment_ids()` which accepts parameters `page_number` and `page_size` and returns a list of integers of the FHRSID of each establishment on the page.
#
# - This function should gracefully handle any records which do not have a FHRSID attribute by putting `None` in the list instead of the FHRSID.
# - If the `page_number` or `page_error` parameters are not integers the function should raise a ValueError
# - If there are no more records left to collect, the function should return `None`

# %%
def get_establishment_ids(page_number, page_size):
    headers = {"x-api-version": 2, "accept": "application/json", "content-type":"application/json"}
    data = requests.get('http://api.ratings.food.gov.uk/Establishments/basic/{}/{}'.format(page_number, page_size),headers=headers).json()
    fhrsid_list = [establishment["FHRSID"] if "establishments" in data.keys() else None for establishment in data["establishments"]]
    return fhrsid_list if len(fhrsid_list)>0 else None
get_establishment_ids(500000,12)
# Out:
# None

# %%
get_establishment_ids(30,10)
# Out:
# [245129, 875843, 897987, 786266, 182807, 278192, 29166, 859034, 326620, 360305]

# %%
print(get_establishment_ids(500000,12))
# Out:
# None

# %% [markdown]
# ## Question 1(c)
#
# Write a function `get_establishments`, which accepts the parameter `establishment_ids`, which is a list of the establishment IDs
#
# - The function should iterate through the list of IDs, and download the detailed information for that ID from the API
# - It should not assume that the caller will provide correct IDs.  If an ID does not exist, the function should not add it to the JSON object
# - Use the provided stub function `insert_data(js)` to represent the insertion of data into a database.  The `js` parameter should be a JSON object, or a list of JSON objects.  This function should only be called once within the `get_establishments` function.
# - The `insert_data` function should not be called if the JSON object is empty
# - A `requests.exceptions.HTTPError` should be thrown for a 4XX or 5XX status code.

# %%
def insert_data(js):
    print("number of establishments added {}".format(len(js)))
    print(js)
    pass

def get_establishments(establishment_ids):
    headers = {"x-api-version": 2, "accept": "application/json", "content-type":"application/json"}
    data_to_add = []
    for id in establishment_ids:
        r = requests.get('http://api.ratings.food.gov.uk/Establishments/{}'.format(id),headers=headers)
        if r.status_code in range(400,600):
            raise requests.exceptions.HTTPError("Error Code {}".format(r.status_code))
        if len(r.json().keys()) > 2:
            data_to_add.append(r.json())
    if len(data_to_add) > 0:
       insert_data(data_to_add)

# %%
get_establishments(get_establishment_ids(100,4))
# Out:
# number of establishments added 4
# [{'FHRSID': 348757, 'links': [], 'AddressLine2': 'Stainland Road', 'Distance': None, 'BusinessTypeID': 1, 'LocalAuthorityWebSite': 'http://www.calderdale.gov.uk', 'AddressLine4': 'Stainland Halifax', 'LocalAuthorityCode': '406', 'SchemeType': 'FHRS', 'Phone': '', 'geocode': {'longitude': '-1.881822', 'latitude': '53.672131'}, 'AddressLine3': '', 'meta': {'pageNumber': 1, 'itemCount': 0, 'extractDate': '0001-01-01T00:00:00', 'dataSource': 'Lucene', 'returncode': 'OK', 'pageSize': 1, 'totalCount': 1, 'totalPages': 1}, 'BusinessName': '1885 The Restaurant', 'NewRatingPending': False, 'RatingDate': '2013-12-04T00:00:00', 'LocalAuthorityBusinessID': '88486', 'PostCode': 'HX4 9HF', 'scores': {'Hygiene': 5, 'Structural': 0, 'ConfidenceInManagement': 5}, 'LocalAuthorityEmailAddress': 'environmental.health@calderdale.gov.uk', 'RatingValue': '5', 'AddressLine1': '', 'BusinessType': 'Restaurant/Cafe/Canteen', 'LocalAuthorityName': 'Calderdale', 'RatingKey': 'fhrs_5_en-gb', 'RightToReply': ''}, {'FHRSID': 411633, 'links': [], 'AddressLine2': '', 'Distance': None, 'BusinessTypeID': 1, 'LocalAuthorityWebSite': 'http://www.westminster.gov.uk/', 'AddressLine4': '', 'LocalAuthorityCode': '533', 'SchemeType': 'FHRS', 'Phone': '', 'geocode': {'longitude': '-0.137853', 'latitude': '51.50845'}, 'AddressLine3': '', 'meta': {'pageNumber': 1, 'itemCount': 0, 'extractDate': '0001-01-01T00:00:00', 'dataSource': 'Lucene', 'returncode': 'OK', 'pageSize': 1, 'totalCount': 1, 'totalPages': 1}, 'BusinessName': '189 Piccadilly', 'NewRatingPending': False, 'RatingDate': '2016-04-01T00:00:00', 'LocalAuthorityBusinessID': '00515/0189/0/000', 'PostCode': 'W1J 9ES', 'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 10}, 'LocalAuthorityEmailAddress': 'foodsafety@westminster.gov.uk', 'RatingValue': '4', 'AddressLine1': 'London', 'BusinessType': 'Restaurant/Cafe/Canteen', 'LocalAuthorityName': 'Westminster', 'RatingKey': 'fhrs_4_en-gb', 'RightToReply': ''}, {'FHRSID': 715251, 'links': [], 'AddressLine2': 'Deshar Road', 'Distance': None, 'BusinessTypeID': 1, 'LocalAuthorityWebSite': 'http://www.highland.gov.uk', 'AddressLine4': 'Highland', 'LocalAuthorityCode': '777', 'SchemeType': 'FHIS', 'Phone': '', 'geocode': {'longitude': '-3.757552', 'latitude': '57.248818'}, 'AddressLine3': 'Boat of Garten', 'meta': {'pageNumber': 1, 'itemCount': 0, 'extractDate': '0001-01-01T00:00:00', 'dataSource': 'Lucene', 'returncode': 'OK', 'pageSize': 1, 'totalCount': 1, 'totalPages': 1}, 'BusinessName': '1896 Gallery and Coffee Shop', 'NewRatingPending': False, 'RatingDate': '1900-01-01T00:00:00', 'LocalAuthorityBusinessID': '44110', 'PostCode': 'PH24 3BN', 'scores': {'Hygiene': None, 'Structural': None, 'ConfidenceInManagement': None}, 'LocalAuthorityEmailAddress': 'env.health@highland.gov.uk', 'RatingValue': 'Awaiting Inspection', 'AddressLine1': 'The Old Village Hall', 'BusinessType': 'Restaurant/Cafe/Canteen', 'LocalAuthorityName': 'Highland', 'RatingKey': 'fhis_awaiting_inspection_en-gb', 'RightToReply': ''}, {'FHRSID': 831075, 'links': [], 'AddressLine2': '18A Fore Street', 'Distance': None, 'BusinessTypeID': 1, 'LocalAuthorityWebSite': 'http://www.cornwall.gov.uk', 'AddressLine4': 'St. Ives', 'LocalAuthorityCode': '705', 'SchemeType': 'FHRS', 'Phone': '', 'geocode': {'longitude': '-5.480254', 'latitude': '50.213153'}, 'AddressLine3': 'St Ives', 'meta': {'pageNumber': 1, 'itemCount': 0, 'extractDate': '0001-01-01T00:00:00', 'dataSource': 'Lucene', 'returncode': 'OK', 'pageSize': 1, 'totalCount': 1, 'totalPages': 1}, 'BusinessName': '18A', 'NewRatingPending': False, 'RatingDate': '2015-12-02T00:00:00', 'LocalAuthorityBusinessID': 'CP15_000917', 'PostCode': 'TR26 1AB', 'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5}, 'LocalAuthorityEmailAddress': 'publicprotection@cornwall.gov.uk', 'RatingValue': '5', 'AddressLine1': 'The Attic', 'BusinessType': 'Restaurant/Cafe/Canteen', 'LocalAuthorityName': 'Cornwall', 'RatingKey': 'fhrs_5_en-gb', 'RightT ...

# %%
get_establishments([100000000])
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-82-ec5b8530220d> in <module>()
# ----> 1 get_establishments([100000000])
#
# <ipython-input-73-ab8fedd74108> in get_establishments(establishment_ids)
#       9         r = requests.get('http://api.ratings.food.gov.uk/Establishments/{}'.format(id),headers=headers)
#      10         if r.status_code in range(400,600):
# ---> 11             raise requests.exceptions.HTTPError("error code {}".format(r.status_code))
#      12         if len(r.json().keys()) > 2:
#      13             data_to_add.append(r.json())
#
# HTTPError: error code 404

# %% [markdown]
# # Question 2
#
# Suppose you have completed collecting the data and are storing it in a MongoDB database.  This question will require you to query that data.  The database is called `health_data`, and contains collections for each local authority (e.g., `db.southampton`, `db.swansea`, `db.westminster`), as well as one for the whole of the UK (`db.uk`).  You can see all the collections by running `db.collection_names()`.
#
# Note that you will need to be on the ECS network to complete this question.
#
# ## Question 2(a)
# Using the `MongoClient` class in `PyMongo`, Create a database object `db` with the following information.
# - Server: svm-hf1g10-comp6235-temp.ecs.soton.ac.uk
# - Port: 27017
# - User: COMP6235
# - Password: wkbbsdh8oDY2
# - Database: health_data

# %%
"""
In this cell, the variable db should be defined, as a PyMongo database object connected to health_data.
"""
config = {
    "username":"COMP6235",
    "password":"wkbbsdh8oDY2",
    "host":"svm-hf1g10-comp6235-temp.ecs.soton.ac.uk",
    "port":"27017",
    "db":"health_data"
}

Config = type("conf", (object,), config)

uri = "mongodb://{c.username}:{c.password}@{c.host}:{c.port}".format(c=Config)
print(uri)
client = MongoClient(uri)
db = client.health_data
db.collection_names()
# Out:
# mongodb://COMP6235:wkbbsdh8oDY2@svm-hf1g10-comp6235-temp.ecs.soton.ac.uk:27017
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-115-38c0318e087d> in <module>()
#      16 client = MongoClient(uri)
#      17 db = client.health_data
# ---> 18 db.collection_names()
#      19
#
# /usr/local/lib/python3.5/dist-packages/pymongo/database.py in collection_names(self, include_system_collections)
#     515         """
#     516         with self.__client._socket_for_reads(
# --> 517                 ReadPreference.PRIMARY) as (sock_info, slave_okay):
#     518
#     519             wire_version = sock_info.max_wire_version
#
# /usr/lib/python3.5/contextlib.py in __enter__(self)
#      57     def __enter__(self):
#      58         try:
# ---> 59             return next(self.gen)
#      60         except StopIteration:
#      61             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.5/dist-packages/pymongo/mongo_client.py in _socket_for_reads(self, read_preference)
#     796         topology = self._get_topology()
#     797         single = topology.description.topology_type == TOPOLOGY_TYPE.Single
# --> 798         with self._get_socket(read_preference) as sock_info:
#     799             slave_ok = (single and not sock_info.is_mongos) or (
#     800                 preference != ReadPreference.PRIMARY)
#
# /usr/lib/python3.5/contextlib.py in __enter__(self)
#      57     def __enter__(self):
#      58         try:
# ---> 59             return next(self.gen)
#      60         except StopIteration:
#      61             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.5/dist-packages/pymongo/mongo_client.py in _get_socket(self, selector)
#     760     @contextlib.contextmanager
#     761     def _get_socket(self, selector):
# --> 762         server = self._get_topology().select_server(selector)
#     763         try:
#     764             with server.get_socket(self.__all_credentials) as sock_info:
#
# /usr/local/lib/python3.5/dist-packages/pymongo/topology.py in select_server(self, selector, server_selection_timeout, address)
#     208         return random.choice(self.select_servers(selector,
#     209                                                  server_selection_timeout,
# --> 210                                                  address))
#     211
#     212     def select_server_by_address(self, address,
#
# /usr/local/lib/python3.5/dist-packages/pymongo/topology.py in select_servers(self, selector, server_selection_timeout, address)
#     184                 if server_timeout == 0 or now > end_time:
#     185                     raise ServerSelectionTimeoutError(
# --> 186                         self._error_message(selector))
#     187
#     188                 self._ensure_opened()
#
# ServerSelectionTimeoutError: svm-hf1g10-comp6235-temp.ecs.soton.ac.uk:27017: timed out

# %% [markdown]
# ## Question 2(b)
#
# Write a function `get_count`, which takes a PyMongo collection object as a parameter and returns the amount of businesses in the collection.

# %%
def get_count(collection):
    """
    Return an integer which gives the amount of unique businesses in the given collection
    """
    # YOUR CODE HERE
    raise NotImplementedError()

# %% [markdown]
# ## Question 2(c)
#
# Write a function `get_rating_value_percentage` which returns the percentage of businesses which were awarded an overall `RatingValue` of 5?  The function should accept a parameter `collection` of type `Collection`, for which it should return the percentage for.

# %%
def get_rating_value_percentage(collection):
    """
    Return a float between 0 and 1 of the amount with a RatingValue of 5
    """
    # YOUR CODE HERE
    raise NotImplementedError()

# %% [markdown]
# ## Question 2(d)
#
# What was the earliest and latest dates that an inspection was carried out? Write a function which returns a dictionary in the form `{'earliest_date': 'YYYY-MM-DD', 'latest_date': 'YYYY-MM-DD'}`.

# %%
from datetime import datetime
def get_earliest_and_latest_dates(collection):
    # YOUR CODE HERE
    raise NotImplementedError()

# %% [markdown]
# ## Question 2(e)
#
# Write a function `get_nearest_establishment_by_gps()` which returns the nearest eating establishment to the given GPS co-ordinates.  It should have two parameters:
# - `collection` - A Python collection object
# - `gps_dict` which is a dict in the format `{'lat': lat_value, 'lng': 'lng_value'}`
#
# The `Geocode` field has a 2dsphere index which you will need for this answer.

# %%
def get_nearest_establishment_by_gps(collection, gps_dict):
    # YOUR CODE HERE
    raise NotImplementedError()
